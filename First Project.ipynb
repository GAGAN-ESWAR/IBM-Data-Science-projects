# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Gagan**
#
# Data Scientist

# %% [markdown]
# *I am intrested in Data Science because of my intrest in contributing for healthcare. Data Science can be used to increase the quality of healthcare by helping understanding the patient and suggesting him perfect medication based on the huge past data available.*

# %% [markdown]
# ### The below should print ' I love Data Science '

# %%
print("I love Data Science")
# Out:
# I love Data Science

# %% [markdown]
# 1. First Item
# 2. Second Item
# 3. Third Item
#
# ***
#
# - First Item
# - Second Item
# - Third Item
#
# ***
#
# ![Screenshot%202022-07-03%20092230.png](attachment:Screenshot%202022-07-03%20092230.png)
